# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
pip install  citipy
# Out:
# Requirement already satisfied: citipy in c:\users\ksarn\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\ksarn\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather_response = requests.get(city_url)
        city_weather = city_weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 2 of Set 1 | margaret river
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | dombarovskiy
# Processing Record 5 of Set 1 | darwin
# Processing Record 6 of Set 1 | isiro
# Processing Record 7 of Set 1 | tazovsky
# Processing Record 8 of Set 1 | tomatlan
# Processing Record 9 of Set 1 | north shore
# Processing Record 10 of Set 1 | talnakh
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | bontang
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | mao
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | chipiona
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | al jawf
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | maralal
# Processing Record 22 of Set 1 | susuman
# Processing Record 23 of Set 1 | nizhnesortymskiy
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | anadyr
# Processing Record 26 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 27 of Set 1 | port augusta
# Processing Record 28 of Set 1 | qaqortoq
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | priozersk
# Processing Record 31 of Set 1 | mana
# Processing Record 32 of Set 1 | vilyuchinsk
# Processing Record 33 of Set 1 | cill airne
# Processing Record 34 of Set 1 | weno
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | belmonte
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 39 of Set 1 | groveland
# Processing Record 40 of Set 1 | grytviken
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | san felipe
# Processing Record 43 of Set 1 | dunedin
# Processing Record 44 of Set 1 | fort saskatchewan
# Processing Record 45 of Set 1 | enewetak
# Processing Record 46 of Set 1 | am djarass
# City not found. Skipping...
# Processing Record 47 of Set 1 | strezhevoy
# Processing Record 48 of Set 1 | saguenay
# Processing Record 49 of Set 1 | longyearbyen
# Processing Record 50 of Set 1 | gillette
# Processing Record 0 of Set 2 | as sulayyil
# Processing Record 1 of Set 2 | atafu village
# Processing Record 2 of Set 2 | udachny
# Processing Record 3 of Set 2 | les sables-d'olonne
# Processing Record 4 of Set 2 | mongoumba
# Processing Record 5 of Set 2 | beau vallon
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | al-`ula
# City not found. Skipping...
# Processing Record 8 of Set 2 | nemuro
# Processing Record 9 of Set 2 | nushki
# Processing Record 10 of Set 2 | trenggalek
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | whitehorse
# Processing Record 13 of Set 2 | acapulco de juarez
# Processing Record 14 of Set 2 | cotonou
# Processing Record 15 of Set 2 | gaigeturi
# Processing Record 16 of Set 2 | caleta olivia
# Processing Record 17 of Set 2 | hamilton
# Processing Record 18 of Set 2 | alaverdi
# Processing Record 19 of Set 2 | klyuchi
# Processing Record 20 of Set 2 | olonkinbyen
# Processing Record 21 of Set 2 | waitangi
# Processing Record 22 of Set 2 | mahalapye
# Processing Record 23 of Set 2 | walvis bay
# Processing Record 24 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 25 of Set 2 | edinburgh of the seven seas
# Processing Record 26 of Set 2 | orcopampa
# Processing Record 27 of Set 2 | brownwood
# Processing Record 28 of Set 2 | chibougamau
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | auki
# Processing Record 31 of Set 2 | sabang
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | launceston
# Processing Record 35 of Set 2 | tura
# Processing Record 36 of Set 2 | okhotsk
# Processing Record 37 of Set 2 | nuuk
# Processing Record 38 of Set 2 | dudinka
# Processing Record 39 of Set 2 | chinde
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | vila franca do campo
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | kailua-kona
# Processing Record 44 of Set 2 | egilsstadir
# Processing Record 45 of Set 2 | lompoc
# Processing Record 46 of Set 2 | rabo de peixe
# Processing Record 47 of Set 2 | eyl
# Processing Record 48 of Set 2 | namibe
# Processing Record 49 of Set 2 | thinadhoo
# Processing Record 0 of Set 3 | la'ie
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | utrik
# Processing Record 3 of Set 3 | stanley
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | gobernador virasora
# Processing Record 6 of Set 3 | lihue
# Processing Record 7 of Set 3 | daruvar
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | mawlaik
# Processing Record 10 of Set 3 | zomin shaharchasi
# City not found. Skipping...
# Processing Record 11 of Set 3 | praia da vitoria
# Processing Record 12 of Set 3 | takoradi
# Processing Record 13 of Set 3 | tobi village
# City not found. Skipping...
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | hobyo
# Processing Record 16 of Set 3 | port mathurin
# Processing Record 17 of Set 3 | palafrugell
# Processing Record 18 of Set 3 | kununurra
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | ranong
# Processing Record 21 of Set 3 | masterton
# Processing Record 22 of Set 3 | tosontsengel
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | hengchun
# Processing Record 25 of Set 3 | saldanha
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 65
#      62         pass
#      64     # pause to avoid rate limiting
# ---> 65     time.sleep(1)
#      67 # Indicate that Data Loading is complete
#      68 print("-----------------------------")
#
# KeyboardInterrupt:

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.dataframe(city_data)

# Show Record Count
city_data_df.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Convert the cities weather data into a Pandas DataFrame
# ----> 2 city_data_df = pd.dataframe(city_data)
#       4 # Show Record Count
#       5 city_data_df.count()
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
# Display sample data
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Display sample data
# ----> 2 city_data_df.head()
#
# NameError: name 'city_data_df' is not defined

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Export the City_Data into a csv
# ----> 2 city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
#
# NameError: name 'city_data_df' is not defined

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature {2024-06-17}")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker = "o", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity {2024-06-17}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolor = "black")
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (Date)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker = "o", edgecolor = "black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (Date)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
#create variables to create linear regression plots

x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0,:]
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,5.8),fontsize=15,color="red")
plt.title("Latitude vs Max Temp")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25.8,3.8),fontsize=15,color="red")
plt.title("Latitude vs Max Temp")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.41210571686072434

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45.8,9.8),fontsize=15,color="red")
plt.title("Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.05689741545789598

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-52.8,4.8),fontsize=15,color="red")
plt.title("Latitude vs Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.0002808747046324606

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45.8,9.8),fontsize=15,color="red")
plt.title("Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.024026517125811032

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55.8,30.8),fontsize=15,color="red")
plt.title("Latitude vs Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45.8,10.8),fontsize=15,color="red")
plt.title("Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.030396762354449474

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25.8,12.8),fontsize=15,color="red")
plt.title("Latitude vs Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r^2-value is: {rvalue**2}")
plt.show()
# Out:
# The r^2-value is: 0.06223904070051575

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
looking at the graphs, i can acertain that there is no correlation and they are all  over the place. The r values also  doesnt give a strong reflection that the latitude correlates with  the wind. It seems to be other factors  that are not presented to explain further.
